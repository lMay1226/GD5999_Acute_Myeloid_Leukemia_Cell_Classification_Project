# %%
# Import the required libraries

import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms, models
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from itertools import product
from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
from torchvision import transforms, datasets, utils

# %%
# Load data set
# Defines a data loader that gets the training set and the validation set
# Reference to open source code: https://github.com/TiezhuXing01/AlexNet_in_PyTorch/blob/main/AlexNet.ipynb
def get_data_loaders(data_dir, batch_size):
    """
    Function to get data loaders for training, validation(, and testing).
    """
    # Normalization
    # The selection of parameters is based on the open source code: https://blog.csdn.net/hhhhhhhhhhwwwwwwwwww/article/details/117709702
    normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                     std=[0.5, 0.5, 0.5])

    # Define transformations
    # The reason why I chose 224 as the size of image is that the AlexNet model needs 224 as input size.
    transform = transforms.Compose([
        transforms.Resize(224),
        transforms.ToTensor(),
        normalize
    ])

    # Load datasets using ImageFolder
    train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, 'train'), transform=transform)
    val_dataset = datasets.ImageFolder(root=os.path.join(data_dir, 'validation'), transform=transform)
    #test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, 'test'), transform=transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4)
    #test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    #return train_loader, val_loader, test_loader
    return train_loader, val_loader

# %%
import os

def count_tiff_images_in_directory(directory):
    # List to hold all .tiff image files
    tiff_files = []

    # Walk through the directory and its subdirectories
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.tiff'):
                tiff_files.append(file)

    # Return the number of .tiff files
    return len(tiff_files)

train_dir = '/home/ym62/Group_Classification/train'
validation_dir = '/home/ym62/Group_Classification/validation'

# Count the number of .tiff images
train_image_count = count_tiff_images_in_directory(train_dir)
validation_image_count = count_tiff_images_in_directory(validation_dir)

print(f'Number of .tiff images in train directory: {train_image_count}')
print(f'Number of .tiff images in validation directory: {validation_image_count}')
# Out:
# Number of .tiff images in train directory: 35592
# Number of .tiff images in validation directory: 1836

# %%
# If CUDA is available, use GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Print the device to confirm if CUDA is being used
print(f'Device being used: {device}')
# Out:
# Device being used: cuda:0

# %%
from PIL import Image
image = Image.open('/home/ym62/Group_Classification/train/LLO/EBO_0002.tiff')
channels = image.mode
print("image channel number is:",channels)
# Out:
# image channel number is: RGBA

# %%
# Define the AlexNet model
# Reference to open source code: https://blog.csdn.net/hhhhhhhhhhwwwwwwwwww/article/details/117709702

class AlexNet(nn.Module):
    def __init__(self, num_classes=1000, init_weights=False):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 48, kernel_size=11, stride=4, padding=2),  # input[3, 224, 224]  output[48, 55, 55]
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # output[48, 27, 27]
            nn.Conv2d(48, 128, kernel_size=5, padding=2),           # output[128, 27, 27]
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # output[128, 13, 13]
            nn.Conv2d(128, 192, kernel_size=3, padding=1),          # output[192, 13, 13]
            nn.ReLU(inplace=True),
            nn.Conv2d(192, 192, kernel_size=3, padding=1),          # output[192, 13, 13]
            nn.ReLU(inplace=True),
            nn.Conv2d(192, 128, kernel_size=3, padding=1),          # output[128, 13, 13]
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),                  # output[128, 6, 6]
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(128 * 6 * 6, 2048),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(2048, 2048),
            nn.ReLU(inplace=True),
            nn.Linear(2048, num_classes),
        )
        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, start_dim=1)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

# %%
# Initialization model
model = AlexNet(num_classes=3).to(device)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 48, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=4608, out_features=2048, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=2048, out_features=2048, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=2048, out_features=3, bias=True)
#   )
# )

# %%
loss_function = nn.CrossEntropyLoss()

# %%
# Reference code from open source: https://gitcode.csdn.net/65ec48271a836825ed7966e5.html?dp_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NjQyOTUwNywiZXhwIjoxNzIyOTEzMDY4LCJpYXQiOjE3MjIzMDgyNjgsInVzZXJuYW1lIjoiaXBrMjAyMiJ9.z-CfUXMfOp6xRJAyjlB4LScNSMSPrx3O3mFaKobykmU
# Define training function
def train(dataloader, model, loss_function, optimizer):
    loss, current, n = 0.0, 0.0, 0
    train_loss = []
    train_acc = []
    train_preds = []
    train_labels = []
    # dataloader: Incoming data (data includes: training data and labels)
    # enumerate()：Used to combine an traversable data object (such as a list, tuple, or string) into an index sequence, listing both data and data subscripts, commonly used in a for loop
    # enumerate There are two return values: one is the sequence number and the other is the data (including the training data and the label).
    # x：Training data (inputs) (tensor type)，y: labels (tensor type)
    for batch, (x, y) in enumerate(dataloader):
        # Forward propagation
        image, y = x.to(device), y.to(device)
        # Calculate the training value
        output = model(image)
        # Calculate the loss function of the observed value (label) and the training value
        cur_loss = loss_function(output, y)
        # torch.max(input, dim) fuction
        # input is the concrete tensor, dim is the dimension of the max function index, 0 is the maximum value per column, and 1 is the maximum value output per row
        # The function returns two tensors, the first of which is the maximum value of each row; The second tensor is the index of the maximum value of each row
        
        _, pred = torch.max(output, axis=1)
        # Calculate the accuracy of each batch
        # Output.shape [0] is the number of the batch, the one-dimensional length of the output
        # torch.sum() sums a dimension of the input tensor data
        cur_acc = torch.sum(y == pred)/output.shape[0]

        # counterpropagation
        # Clear past gradient
        optimizer.zero_grad()
        # Back propagation, calculate the current gradient
        cur_loss.backward()
        # Update network parameters according to gradient
        optimizer.step()
        # item() : Gets the element value of the element tensor
        loss += cur_loss.item()
        current += cur_acc.item()
        n = n + 1



        # Collect predictions and labels
        train_preds.extend(pred.cpu().numpy())
        train_labels.extend(y.cpu().numpy())

    
    #_, preds = torch.max(output, 1)
    train_loss = loss / n
    train_acc = current / n




    # Calculate the error rate of the training
    print('train_loss==' + str(train_loss))
    # Calculate the accuracy of the training
    print('train_acc' + str(train_acc))
    return train_loss, train_acc, train_labels, train_preds


# Define validation function
def val(dataloader, model, loss_function):
    loss, current, n = 0.0, 0.0, 0
    val_loss = []
    val_acc = []
    val_preds = []
    val_labels = []

    # eval() : Disable if Batch Normalization and Dropout are present in the model, in case the weights are changed
    model.eval()
    with torch.no_grad():
        for batch, (x, y) in enumerate(dataloader):
            # Forward propagation
            image, y = x.to(device), y.to(device)
            output = model(image)
            cur_loss = loss_function(output, y)
            _, pred = torch.max(output, axis=1)
            cur_acc = torch.sum(y == pred)/output.shape[0]
            loss += cur_loss.item()
            current += cur_acc.item()
            n = n+1

            val_preds.extend(pred.cpu().numpy())
            val_labels.extend(y.cpu().numpy())

    val_loss = loss / n
    val_acc = current / n
    # Calculate the error rate of validation
    print('val_loss=' + str(val_loss))
    # Calculate the accuracy of the validation
    print('val_acc=' + str(val_acc))
    return val_loss, val_acc, val_labels, val_preds


# Define the drawing function
# Error rate
def matplot_loss(train_loss, val_loss):
    # The parameter label = "" passes in a value of type string, which is the name of the legend
    plt.plot(train_loss, label='train_loss')
    plt.plot(val_loss, label='val_loss')
    # loc represents the position of the legend in the overall axis plane (usually 'best' is selected)
    plt.legend(loc='best')
    plt.xlabel('loss')
    plt.ylabel('epoch')
    plt.title("Comparison of loss values between training set and validation set")
    plt.show()

# accuracy rate
def matplot_acc(train_acc, val_acc):
    plt.plot(train_acc, label = 'train_acc')
    plt.plot(val_acc, label = 'val_acc')
    plt.legend(loc = 'best')
    plt.xlabel('acc')
    plt.ylabel('epoch')
    plt.title("Comparison of acc values of training set and validation set")
    plt.show()


# Reference code from open source: https://openatomworkshop.csdn.net/6673dbe0a1e8811a9781d86b.html?dp_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NjQyOTUwNywiZXhwIjoxNzIyOTEzMDY4LCJpYXQiOjE3MjIzMDgyNjgsInVzZXJuYW1lIjoiaXBrMjAyMiJ9.z-CfUXMfOp6xRJAyjlB4LScNSMSPrx3O3mFaKobykmU
# Define the early stopping class
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path='.'):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decreases.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path + '/checkpoint.pth')
        self.val_loss_min = val_loss

# Begin training
#train_loss = []
#train_acc = []
#val_loss = []
#val_acc = []
#train_preds = []
#train_labels = []
#val_preds = []
#val_labels = []
#all_pred = []
#all_label = []

# %%
# Reference code from open source: https://blog.csdn.net/weixin_43760844/article/details/115208925
# Reference code from open source: https://blog.csdn.net/weixin_45662399/article/details/130131106
# Confusion matrices
# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names, title="Confusion Matrix", cmap=plt.cm.Oranges):

    print(len(y_true))
    print(len(y_pred))


    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    plt.matshow(cm, cmap=cmap, fignum=1)
    plt.colorbar()
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.xticks(range(len(class_names)), class_names, rotation=45)
    plt.yticks(range(len(class_names)), class_names)

    for i in range(len(cm)):
        for j in range(len(cm)):
            plt.annotate(cm[j, i], xy=(i, j), horizontalalignment='center', verticalalignment='center')
    
    plt.show()

# %%
import itertools
from copy import deepcopy

# %%
# Reference code from open source: https://www.cnblogs.com/chuqianyu/p/17684614.html
# Hyperparameter tuning
# Define random search function and draw the confusion matrices
def random_search(data_dir, param_space):
    # Generate all possible hyperparameter combinations
    param_combinations = list(itertools.product(*param_space.values()))
    np.random.shuffle(param_combinations)  # Shuffle the combinations to explore randomly

    best_score = -1
    best_params = None
    best_model = None

    for i, combination in enumerate(param_combinations):
        # Set the hyperparameters
        lr, batch_size = combination

        print(f'Iteration {i+1}/{len(param_combinations)}, Params: {{\'learning_rate\': {lr}, \'batch_size\': {batch_size}}}')

        # Get data loaders
        train_loader, val_loader = get_data_loaders(data_dir, batch_size)

        # Initialize model, criterion, and optimizer
        model = AlexNet(num_classes=3).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
        # optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-3)

        # Train the model for 50 epochs (smaller than 100)
        # The number of patience refers: https://openatomworkshop.csdn.net/6673dbe0a1e8811a9781d86b.html?dp_token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NjQyOTUwNywiZXhwIjoxNzIyOTEzMDY4LCJpYXQiOjE3MjIzMDgyNjgsInVzZXJuYW1lIjoiaXBrMjAyMiJ9.z-CfUXMfOp6xRJAyjlB4LScNSMSPrx3O3mFaKobykmU
        early_stopping = EarlyStopping(patience=7, verbose=True)


        # The number of epoch during hyperparameter refers Rhona McCracken's Dissertation
        for epoch in range(50):
            print(f'Epoch {epoch+1}/50')
            train_loss, train_acc, train_labels, train_preds = train(train_loader, model, criterion, optimizer)
            val_loss, val_acc, val_labels, val_preds = val(val_loader, model, criterion)

            early_stopping(val_loss, model)
            if early_stopping.early_stop:
                print("Early stopping")
                break

        # Evaluate model performance
        if val_acc > best_score:
            best_score = val_acc
            best_params = {'learning_rate': lr, 'batch_size': batch_size}
            best_model = deepcopy(model)  # Store the best model

        # Confusion matrix for current model
        classes = train_loader.dataset.classes
        plot_confusion_matrix(train_labels, train_preds, classes, title=f'Training Set Confusion Matrix for Iteration {i+1}')
        plot_confusion_matrix(val_labels, val_preds, classes, title=f'Validation Set Confusion Matrix for Iteration {i+1}')

    return best_score, best_params, best_model

# Define hyperparameter space
param_space = {
    'learning_rate': [1e-5, 1e-4],
    'batch_size': [32, 64]
}

# Perform random search
data_dir = '/home/ym62/Group_Classification/'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'Device being used: {device}')

best_score, best_params, best_model = random_search(data_dir, param_space)

print('Best accuracy:', best_score)
print('The best hyperparameters:', best_params)
# Out:
# Device being used: cuda:0
# Iteration 1/4, Params: {'learning_rate': 0.0001, 'batch_size': 32}
# Epoch 1/50
# /home/ym62/project/venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# train_loss==0.2651462112883941
# train_acc0.8923798292902066
# val_loss=0.2790233239708147
# val_acc=0.9030172413793104
# Validation loss decreased (inf --> 0.279023).  Saving model ...
# Epoch 2/50
# train_loss==0.10010177719968255
# train_acc0.9634433962264151
# val_loss=0.14976539025243757
# val_acc=0.9466594827586207
# Validation loss decreased (0.279023 --> 0.149765).  Saving model ...
# Epoch 3/50
# train_loss==0.07898543664718498
# train_acc0.9720911949685535
# val_loss=0.1148356654127289
# val_acc=0.9601293103448276
# Validation loss decreased (0.149765 --> 0.114836).  Saving model ...
# Epoch 4/50
# train_loss==0.06817524700909008
# train_acc0.9755446990116802
# val_loss=0.10504319688680912
# val_acc=0.962823275862069
# Validation loss decreased (0.114836 --> 0.105043).  Saving model ...
# Epoch 5/50
# train_loss==0.05861273698124558
# train_acc0.9795878256963163
# val_loss=0.28604575684936395
# val_acc=0.9091235635609463
# EarlyStopping counter: 1 out of 7
# Epoch 6/50
# train_loss==0.05568046823127433
# train_acc0.9806828391734053
# val_loss=0.10461739251469884
# val_acc=0.9682112068965517
# Validation loss decreased (0.105043 --> 0.104617).  Saving model ...
# Epoch 7/50
# train_loss==0.05359674437408338
# train_acc0.9814409254267745
# val_loss=0.14387346374829138
# val_acc=0.9455818965517241
# EarlyStopping counter: 1 out of 7
# Epoch 8/50
# train_loss==0.04745934821152976
# train_acc0.9840801886792453
# val_loss=0.2184448057039468
# val_acc=0.9326508620689655
# EarlyStopping counter: 2 out of 7
# Epoch 9/50
# train_loss==0.04526233969391263
# train_acc0.9838555705300989
# val_loss=0.09621414928438628
# val_acc=0.96875
# Validation loss decreased (0.104617 --> 0.096214).  Saving model ...
# Epoch 10/50
# train_loss==0.04033438038136994
# train_acc0.9863263701707098
# val_loss=0.10377720504546797
# val_acc=0.9671336206896551
# EarlyStopping counter: 1 out of 7
# Epoch 11/50
# train_loss==0.03529100073779955
# train_acc0.9876460017969452
# val_loss=0.18191085980336946
# val_acc=0.9488146551724138
# EarlyStopping counter: 2 out of 7
# Epoch 12/50
# train_loss==0.032941142778762596
# train_acc0.9889937106918238
# val_loss=0.11416002961017127
# val_acc=0.9660560344827587
# EarlyStopping counter: 3 out of 7
# Epoch 13/50
# train_loss==0.03066988188493678
# train_acc0.9900044923629829
# val_loss=0.12297951838180435
# val_acc=0.9676724137931034
# EarlyStopping counter: 4 out of 7
# Epoch 14/50
# train_loss==0.029036005821776355
# train_acc0.9896675651392632
# val_loss=0.12818382976058337
# val_acc=0.9633620689655172
# EarlyStopping counter: 5 out of 7
# Epoch 15/50
# train_loss==0.023462856380644274
# train_acc0.992306828391734
# val_loss=0.1614987229671395
# val_acc=0.9633620689655172
# EarlyStopping counter: 6 out of 7
# Epoch 16/50
# train_loss==0.025046613761631253
# train_acc0.9916891284815813
# val_loss=0.13982755106829653
# val_acc=0.9542025862068966
# EarlyStopping counter: 7 out of 7
# Early stopping
# 35592
# 35592
# 1836
# 1836
# Iteration 2/4, Params: {'learning_rate': 1e-05, 'batch_size': 32}
# Epoch 1/50
# train_loss==0.49192186260239457
# train_acc0.7968609613656783
# val_loss=0.37664373544976115
# val_acc=0.846084770457498
# Validation loss decreased (inf --> 0.376644).  Saving model ...
# Epoch 2/50
# train_loss==0.1832881036054708
# train_acc0.9355345911949685
# val_loss=0.22277063251762041
# val_acc=0.9139727014919807
# Validation loss decreased (0.376644 --> 0.222771).  Saving model ...
# Epoch 3/50
# train_loss==0.14643680071583737
# train_acc0.9490959119496856
# val_loss=0.1790056641791658
# val_acc=0.9358836206896551
# Validation loss decreased (0.222771 --> 0.179006).  Saving model ...
# Epoch 4/50
# train_loss==0.12546899121987692
# train_acc0.9560029200359389
# val_loss=0.1702151417748296
# val_acc=0.9272629310344828
# Validation loss decreased (0.179006 --> 0.170215).  Saving model ...
# Epoch 5/50
# train_loss==0.11136017976912795
# train_acc0.9610287511230907
# val_loss=0.16675879637678637
# val_acc=0.9418103448275862
# Validation loss decreased (0.170215 --> 0.166759).  Saving model ...
# Epoch 6/50
# train_loss==0.10014984600378998
# train_acc0.9634995507637018
# val_loss=0.1785038568496961
# val_acc=0.9331896551724138
# EarlyStopping counter: 1 out of 7
# Epoch 7/50
# train_loss==0.09102833249375245
# train_acc0.966363432165319
# val_loss=0.12945411503033968
# val_acc=0.9574353448275862
# Validation loss decreased (0.166759 --> 0.129454).  Saving model ...
# Epoch 8/50
# train_loss==0.08611517472662072
# train_acc0.9686938454627134
# val_loss=0.1483524596150001
# val_acc=0.9445043103448276
# EarlyStopping counter: 1 out of 7
# Epoch 9/50
# train_loss==0.07871112507045845
# train_acc0.9720350404312669
# val_loss=0.13908911330609358
# val_acc=0.9482758620689655
# EarlyStopping counter: 2 out of 7
# Epoch 10/50
# train_loss==0.07576072003913295
# train_acc0.972512353998203
# val_loss=0.13108751708481076
# val_acc=0.953125
# EarlyStopping counter: 3 out of 7
# Epoch 11/50
# train_loss==0.07126102283099534
# train_acc0.9737758310871518
# val_loss=0.12384065754856144
# val_acc=0.9547413793103449
# Validation loss decreased (0.129454 --> 0.123841).  Saving model ...
# Epoch 12/50
# train_loss==0.06776805507163086
# train_acc0.9759658580413297
# val_loss=0.16657279186946308
# val_acc=0.9401939655172413
# EarlyStopping counter: 1 out of 7
# Epoch 13/50
# train_loss==0.0659957676655249
# train_acc0.9766397124887691
# val_loss=0.09904916527488365
# val_acc=0.9644396551724138
# Validation loss decreased (0.123841 --> 0.099049).  Saving model ...
# Epoch 14/50
# train_loss==0.0617135940695948
# train_acc0.9779874213836478
# val_loss=0.18403509520957695
# val_acc=0.9358836206896551
# EarlyStopping counter: 1 out of 7
# Epoch 15/50
# train_loss==0.06129474044038587
# train_acc0.9779312668463612
# val_loss=0.1092821464819657
# val_acc=0.9585129310344828
# EarlyStopping counter: 2 out of 7
# Epoch 16/50
# train_loss==0.05833339683892689
# train_acc0.9790824348607368
# val_loss=0.10023832155224979
# val_acc=0.962823275862069
# EarlyStopping counter: 3 out of 7
# Epoch 17/50
# train_loss==0.05649568042772264
# train_acc0.9795878256963163
# val_loss=0.11470146310025954
# val_acc=0.9568965517241379
# EarlyStopping counter: 4 out of 7
# Epoch 18/50
# train_loss==0.05396437993069595
# train_acc0.9807109164420486
# val_loss=0.09927292822675522
# val_acc=0.9660560344827587
# EarlyStopping counter: 5 out of 7
# Epoch 19/50
# train_loss==0.05201390391908735
# train_acc0.981300539083558
# val_loss=0.09737661323592404
# val_acc=0.9644396551724138
# Validation loss decreased (0.099049 --> 0.097377).  Saving model ...
# Epoch 20/50
# train_loss==0.050996510145758164
# train_acc0.9818059299191375
# val_loss=0.10785753244397647
# val_acc=0.9639008620689655
# EarlyStopping counter: 1 out of 7
# Epoch 21/50
# train_loss==0.05122208763607414
# train_acc0.9814690026954178
# val_loss=0.09028095825462891
# val_acc=0.9644396551724138
# Validation loss decreased (0.097377 --> 0.090281).  Saving model ...
# Epoch 22/50
# train_loss==0.04620131855869878
# train_acc0.983967879604672
# val_loss=0.10363823695686357
# val_acc=0.9612068965517241
# EarlyStopping counter: 1 out of 7
# Epoch 23/50
# train_loss==0.047616292012734915
# train_acc0.9830132524707996
# val_loss=0.08779559743887713
# val_acc=0.9676724137931034
# Validation loss decreased (0.090281 --> 0.087796).  Saving model ...
# Epoch 24/50
# train_loss==0.043707576234969715
# train_acc0.9843890386343217
# val_loss=0.09494056070779434
# val_acc=0.9676724137931034
# EarlyStopping counter: 1 out of 7
# Epoch 25/50
# train_loss==0.0436803058928539
# train_acc0.984697888589398
# val_loss=0.08859155445980864
# val_acc=0.9676724137931034
# EarlyStopping counter: 2 out of 7
# Epoch 26/50
# train_loss==0.04114045759172222
# train_acc0.9853436657681941
# val_loss=0.08725640962564221
# val_acc=0.96875
# Validation loss decreased (0.087796 --> 0.087256).  Saving model ...
# Epoch 27/50
# train_loss==0.0422106611438383
# train_acc0.9846136567834681
# val_loss=0.09485352955737747
# val_acc=0.9692887931034483
# EarlyStopping counter: 1 out of 7
# Epoch 28/50
# train_loss==0.03987054699593201
# train_acc0.9857648247978437
# val_loss=0.0973303339013565
# val_acc=0.9665948275862069
# EarlyStopping counter: 2 out of 7
# Epoch 29/50
# train_loss==0.03744696567248148
# train_acc0.9869440700808625
# val_loss=0.1314729440672291
# val_acc=0.9558189655172413
# EarlyStopping counter: 3 out of 7
# Epoch 30/50
# train_loss==0.03651927537604855
# train_acc0.987168688230009
# val_loss=0.08578996941713708
# val_acc=0.9703663793103449
# Validation loss decreased (0.087256 --> 0.085790).  Saving model ...
# Epoch 31/50
# train_loss==0.03636549474089511
# train_acc0.9872529200359389
# val_loss=0.09046548971359855
# val_acc=0.9655172413793104
# EarlyStopping counter: 1 out of 7
# Epoch 32/50
# train_loss==0.03474308004738137
# train_acc0.987814465408805
# val_loss=0.10234422218905068
# val_acc=0.9671336206896551
# EarlyStopping counter: 2 out of 7
# Epoch 33/50
# train_loss==0.03361402821813336
# train_acc0.9887971698113207
# val_loss=0.10399940950289953
# val_acc=0.9682112068965517
# EarlyStopping counter: 3 out of 7
# Epoch 34/50
# train_loss==0.03263004588109187
# train_acc0.9886848607367476
# val_loss=0.08874583954077715
# val_acc=0.9682112068965517
# EarlyStopping counter: 4 out of 7
# Epoch 35/50
# train_loss==0.031381423164222655
# train_acc0.9899483378256964
# val_loss=0.1047124355998927
# val_acc=0.9682112068965517
# EarlyStopping counter: 5 out of 7
# Epoch 36/50
# train_loss==0.029707113477140574
# train_acc0.9904537286612758
# val_loss=0.1060111652259052
# val_acc=0.9671336206896551
# EarlyStopping counter: 6 out of 7
# Epoch 37/50
# train_loss==0.028844769740707734
# train_acc0.9900606469002695
# val_loss=0.1399137552622239
# val_acc=0.9595905172413793
# EarlyStopping counter: 7 out of 7
# Early stopping
# 35592
# 35592
# 1836
# 1836
# Iteration 3/4, Params: {'learning_rate': 1e-05, 'batch_size': 64}
# Epoch 1/50
# train_loss==0.6736006636165844
# train_acc0.7013577199281867
# val_loss=0.5106641254548369
# val_acc=0.792662618489101
# Validation loss decreased (inf --> 0.510664).  Saving model ...
# Epoch 2/50
# train_loss==0.23579579512831125
# train_acc0.9177232944344704
# val_loss=0.26192056005499487
# val_acc=0.9054663016878325
# Validation loss decreased (0.510664 --> 0.261921).  Saving model ...
# Epoch 3/50
# train_loss==0.1771583311941936
# train_acc0.9386781867145422
# val_loss=0.20988076218757137
# val_acc=0.9256465517241379
# Validation loss decreased (0.261921 --> 0.209881).  Saving model ...
# Epoch 4/50
# train_loss==0.15409796074353813
# train_acc0.9449337971274686
# val_loss=0.2050988415159799
# val_acc=0.9256465517241379
# Validation loss decreased (0.209881 --> 0.205099).  Saving model ...
# Epoch 5/50
# train_loss==0.14156157630403765
# train_acc0.9504039497307002
# val_loss=0.21822473295996414
# val_acc=0.9170258620689655
# EarlyStopping counter: 1 out of 7
# Epoch 6/50
# train_loss==0.12755403504832322
# train_acc0.954443447037702
# val_loss=0.19938572348448738
# val_acc=0.9294181034482759
# Validation loss decreased (0.205099 --> 0.199386).  Saving model ...
# Epoch 7/50
# train_loss==0.1154462445620949
# train_acc0.9598574955116697
# val_loss=0.19286408492139187
# val_acc=0.931573275862069
# Validation loss decreased (0.199386 --> 0.192864).  Saving model ...
# Epoch 8/50
# train_loss==0.10971224703617007
# train_acc0.9613162028725314
# val_loss=0.14808195849463088
# val_acc=0.9574353448275862
# Validation loss decreased (0.192864 --> 0.148082).  Saving model ...
# Epoch 9/50
# train_loss==0.10325673998699689
# train_acc0.9628029622980251
# val_loss=0.19572959674907656
# val_acc=0.9256465517241379
# EarlyStopping counter: 1 out of 7
# Epoch 10/50
# train_loss==0.09595667011994045
# train_acc0.9650751795332136
# val_loss=0.1875879930669506
# val_acc=0.9401939655172413
# EarlyStopping counter: 2 out of 7
# Epoch 11/50
# train_loss==0.09072753272890456
# train_acc0.9670107719928187
# val_loss=0.13039700577340635
# val_acc=0.9585129310344828
# Validation loss decreased (0.148082 --> 0.130397).  Saving model ...
# Epoch 12/50
# train_loss==0.08761807476610106
# train_acc0.9677401256732495
# val_loss=0.14949260313256546
# val_acc=0.9488146551724138
# EarlyStopping counter: 1 out of 7
# Epoch 13/50
# train_loss==0.08270437997904617
# train_acc0.9693390933572711
# val_loss=0.12021369583792342
# val_acc=0.9579741379310345
# Validation loss decreased (0.130397 --> 0.120214).  Saving model ...
# Epoch 14/50
# train_loss==0.0806266183858734
# train_acc0.970713644524237
# val_loss=0.1817942019471706
# val_acc=0.9396551724137931
# EarlyStopping counter: 1 out of 7
# Epoch 15/50
# train_loss==0.07520254544455632
# train_acc0.9721442998204668
# val_loss=0.11971081324435513
# val_acc=0.9568965517241379
# Validation loss decreased (0.120214 --> 0.119711).  Saving model ...
# Epoch 16/50
# train_loss==0.0746868628685829
# train_acc0.9741359964093357
# val_loss=0.17574508879574594
# val_acc=0.9348060344827587
# EarlyStopping counter: 1 out of 7
# Epoch 17/50
# train_loss==0.07322279732658477
# train_acc0.9737432675044884
# val_loss=0.11115373671456272
# val_acc=0.9601293103448276
# Validation loss decreased (0.119711 --> 0.111154).  Saving model ...
# Epoch 18/50
# train_loss==0.06781100558244106
# train_acc0.9757910682226212
# val_loss=0.10773622828178461
# val_acc=0.9622844827586207
# Validation loss decreased (0.111154 --> 0.107736).  Saving model ...
# Epoch 19/50
# train_loss==0.06346570269147828
# train_acc0.9773619838420108
# val_loss=0.1257846574981472
# val_acc=0.953125
# EarlyStopping counter: 1 out of 7
# Epoch 20/50
# train_loss==0.06227041277248593
# train_acc0.977221723518851
# val_loss=0.11217901166448177
# val_acc=0.9639008620689655
# EarlyStopping counter: 2 out of 7
# Epoch 21/50
# train_loss==0.06080953257502837
# train_acc0.9785682226211849
# val_loss=0.12071039950764127
# val_acc=0.9574353448275862
# EarlyStopping counter: 3 out of 7
# Epoch 22/50
# train_loss==0.05853167135114623
# train_acc0.9787926391382405
# val_loss=0.09928295689590821
# val_acc=0.9655172413793104
# Validation loss decreased (0.107736 --> 0.099283).  Saving model ...
# Epoch 23/50
# train_loss==0.057171496521694926
# train_acc0.979802513464991
# val_loss=0.1068061925370471
# val_acc=0.9660560344827587
# EarlyStopping counter: 1 out of 7
# Epoch 24/50
# train_loss==0.056269402461062906
# train_acc0.9807282315978456
# val_loss=0.11805652047142162
# val_acc=0.9525862068965517
# EarlyStopping counter: 2 out of 7
# Epoch 25/50
# train_loss==0.05695099487175072
# train_acc0.979129263913824
# val_loss=0.12692312949040005
# val_acc=0.9568965517241379
# EarlyStopping counter: 3 out of 7
# Epoch 26/50
# train_loss==0.05277509547860313
# train_acc0.9808684919210053
# val_loss=0.10064553438659742
# val_acc=0.9682112068965517
# EarlyStopping counter: 4 out of 7
# Epoch 27/50
# train_loss==0.05207671743192287
# train_acc0.9810929084380611
# val_loss=0.14155046863417173
# val_acc=0.947198275862069
# EarlyStopping counter: 5 out of 7
# Epoch 28/50
# train_loss==0.05426905946212501
# train_acc0.981149012567325
# val_loss=0.12688177949668647
# val_acc=0.9552801724137931
# EarlyStopping counter: 6 out of 7
# Epoch 29/50
# train_loss==0.0498196780526947
# train_acc0.9820186265709157
# val_loss=0.1350069211837073
# val_acc=0.953125
# EarlyStopping counter: 7 out of 7
# Early stopping
# 35592
# 35592
# 1836
# 1836
# Iteration 4/4, Params: {'learning_rate': 0.0001, 'batch_size': 64}
# Epoch 1/50
# train_loss==0.2988020499542864
# train_acc0.8771039048473968
# val_loss=0.19329981549225492
# val_acc=0.9213362068965517
# Validation loss decreased (inf --> 0.193300).  Saving model ...
# Epoch 2/50
# train_loss==0.11203623498886944
# train_acc0.9613723070017953
# val_loss=0.13591568772520485
# val_acc=0.9498922413793104
# Validation loss decreased (0.193300 --> 0.135916).  Saving model ...
# Epoch 3/50
# train_loss==0.08673667804048776
# train_acc0.968778052064632
# val_loss=0.11611644994539755
# val_acc=0.9568965517241379
# Validation loss decreased (0.135916 --> 0.116116).  Saving model ...
# Epoch 4/50
# train_loss==0.07409996621158556
# train_acc0.972593132854578
# val_loss=0.09899638844493391
# val_acc=0.9660560344827587
# Validation loss decreased (0.116116 --> 0.098996).  Saving model ...
# Epoch 5/50
# train_loss==0.06889871456551648
# train_acc0.974584829443447
# val_loss=0.12418614504537706
# val_acc=0.9601293103448276
# EarlyStopping counter: 1 out of 7
# Epoch 6/50
# train_loss==0.05780217212439252
# train_acc0.9799988779174147
# val_loss=0.09163122730789272
# val_acc=0.9692887931034483
# Validation loss decreased (0.098996 --> 0.091631).  Saving model ...
# Epoch 7/50
# train_loss==0.05506920514216971
# train_acc0.9803355026929982
# val_loss=0.1041946559702849
# val_acc=0.9671336206896551
# EarlyStopping counter: 1 out of 7
# Epoch 8/50
# train_loss==0.04771119317824031
# train_acc0.9829723967684022
# val_loss=0.10726897603960643
# val_acc=0.9633620689655172
# EarlyStopping counter: 2 out of 7
# Epoch 9/50
# train_loss==0.046666250278867276
# train_acc0.9838700628366248
# val_loss=0.08393066746969546
# val_acc=0.9719827586206896
# Validation loss decreased (0.091631 --> 0.083931).  Saving model ...
# Epoch 10/50
# train_loss==0.046085912063366714
# train_acc0.9844872082585279
# val_loss=0.13423386434542722
# val_acc=0.9561128534119705
# EarlyStopping counter: 1 out of 7
# Epoch 11/50
# train_loss==0.04809030194313699
# train_acc0.983673698384201
# val_loss=0.09339991129898659
# val_acc=0.96875
# EarlyStopping counter: 2 out of 7
# Epoch 12/50
# train_loss==0.03818419178332498
# train_acc0.9871802064631957
# val_loss=0.1731606356253655
# val_acc=0.9407327586206896
# EarlyStopping counter: 3 out of 7
# Epoch 13/50
# train_loss==0.03359830996853047
# train_acc0.9888633303411131
# val_loss=0.1463181552670872
# val_acc=0.9558189655172413
# EarlyStopping counter: 4 out of 7
# Epoch 14/50
# train_loss==0.03325709174252806
# train_acc0.9883864452423698
# val_loss=0.30273898086582857
# val_acc=0.9103154396188671
# EarlyStopping counter: 5 out of 7
# Epoch 15/50
# train_loss==0.03284548618391832
# train_acc0.9890596947935368
# val_loss=0.12545819183657747
# val_acc=0.9655172413793104
# EarlyStopping counter: 6 out of 7
# Epoch 16/50
# train_loss==0.027646111689089536
# train_acc0.9900976211849192
# val_loss=0.08790193399432485
# val_acc=0.9719827586206896
# EarlyStopping counter: 7 out of 7
# Early stopping
# 35592
# 35592
# 1836
# 1836
# Best accuracy: 0.9719827586206896
# The best hyperparameters: {'learning_rate': 0.0001, 'batch_size': 64}

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
# Train the final model with the best hyperparameters
# Refer to the open source code: https://blog.csdn.net/FUTEROX/article/details/122724634
# Plot loss and accuracy curves on training and validation sets
# Refer to the open source code: https://huaweicloud.csdn.net/6380687adacf622b8df86ee5.html?spm=1001.2101.3001.6661.1&utm_medium=distribute.pc_relevant_t0.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Eactivity-1-121895338-blog-109179583.235%5Ev43%5Epc_blog_bottom_relevance_base6&depth_1-utm_source=distribute.pc_relevant_t0.none-task-blog-2%7Edefault%7EBlogCommendFromBaidu%7Eactivity-1-121895338-blog-109179583.235%5Ev43%5Epc_blog_bottom_relevance_base6&utm_relevant_index=1

# Main training loop


if __name__ == '__main__':
    writer = SummaryWriter()
    module = AlexNet(num_classes=3).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(module.parameters(), lr=best_params['learning_rate'], weight_decay=1e-4)
    num_epochs = 100

    data_dir = '/home/ym62/Group_Classification/'

    # Get data loaders
    train_loader, val_loader = get_data_loaders(data_dir, best_params['batch_size'])

    train_step = 0  # The number of sessions per round
    module.train()  # Model in training state

    # Initialize lists for tracking metrics
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    
    # Initialize early stopping
    # The number of patience refers to website: https://blog.csdn.net/FUTEROX/article/details/122724634
    early_stopping = EarlyStopping(patience=7, verbose=True)

    
    
    for i in range(num_epochs):
        print("Training on the {} round".format(i + 1))
        train_step = 0
        train_total_loss = 0.0
        train_corrects = 0

        # Collect labels and predictions for confusion matrix
        train_labels = []
        train_preds = []

        for data in train_loader:
            imgs, targets = data

            imgs = imgs.to(device)
            targets = targets.to(device)

            # Forward pass
            outputs = module(imgs)
            result_loss = criterion(outputs, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            result_loss.backward()
            optimizer.step()

            # Statistics
            train_step += 1

            train_total_loss += result_loss.item() * imgs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == targets.data)

            train_preds.extend(preds.cpu().numpy())
            train_labels.extend(targets.cpu().numpy())

            if train_step % 100 == 0:
                print("loss for the {} training session of the {} round :{}".format((i + 1), train_step, result_loss.item()))

        train_loss = train_total_loss / len(train_loader.dataset)
        train_acc = train_corrects.double() / len(train_loader.dataset)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        print(f"Epoch {i + 1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")

        # Validation phase
        module.eval()
        val_loss = 0.0
        val_corrects = 0
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for imgs, targets in val_loader:
                imgs, targets = imgs.to(device), targets.to(device)

                outputs = module(imgs)
                result_loss = criterion(outputs, targets)

                val_loss += result_loss.item() * imgs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == targets.data)

                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(targets.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_acc = val_corrects.double() / len(val_loader.dataset)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        # Log metrics
        writer.add_scalar("Loss/Train", train_loss, i)
        writer.add_scalar("Accuracy/Train", train_acc, i)
        writer.add_scalar("Loss/Validation", val_loss, i)
        writer.add_scalar("Accuracy/Validation", val_acc, i)

        print(f"Epoch {i + 1}/{num_epochs} - "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")



        # Check early stopping condition
        early_stopping(val_loss, module)
        if early_stopping.early_stop:
            print("Early stopping")
            break



    writer.close()

    # Plot confusion matrices
    class_names = train_loader.dataset.classes
    plot_confusion_matrix(train_labels, train_preds, class_names, title="Training Set Confusion Matrix")
    plot_confusion_matrix(val_labels, val_preds, class_names, title="Validation Set Confusion Matrix")

    # Plot the loss and accuracy curves
    def plot_curves(train_values, val_values, title, ylabel):



        if isinstance(train_values[0], torch.Tensor):
            train_values = [val.cpu().numpy() for val in train_values]
        if isinstance(val_values[0], torch.Tensor):
            val_values = [val.cpu().numpy() for val in val_values]



        epochs = range(1, len(train_values) + 1)
        plt.figure(figsize=(10, 5))
        plt.plot(epochs, train_values, label='Training')
        plt.plot(epochs, val_values, label='Validation')
        plt.xlabel('Epochs')
        plt.ylabel(ylabel)
        plt.title(title)
        plt.legend()
        plt.grid()
        plt.show()



    train_accuracies_np = [acc.cpu().numpy() if isinstance(acc, torch.Tensor) else acc for acc in train_accuracies]
    val_accuracies_np = [acc.cpu().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracies]
    
    
    
    plot_curves(train_losses, val_losses, 'Loss over Epochs', 'Loss')
    plot_curves(train_accuracies, val_accuracies, 'Accuracy over Epochs', 'Accuracy')
# Out:
# Training on the 1 round
# loss for the 1 training session of the 100 round :0.4506119191646576
# loss for the 1 training session of the 200 round :0.2150566726922989
# loss for the 1 training session of the 300 round :0.25785744190216064
# loss for the 1 training session of the 400 round :0.16957543790340424
# loss for the 1 training session of the 500 round :0.1774270236492157
# Epoch 1/100 - Train Loss: 0.3179, Train Acc: 0.8695
# Epoch 1/100 - Train Loss: 0.3179, Train Acc: 0.8695, Val Loss: 0.2302, Val Acc: 0.9123
# Validation loss decreased (inf --> 0.230164).  Saving model ...
# Training on the 2 round
# loss for the 2 training session of the 100 round :0.23697882890701294
# loss for the 2 training session of the 200 round :0.0864560529589653
# loss for the 2 training session of the 300 round :0.08772947639226913
# loss for the 2 training session of the 400 round :0.17393359541893005
# loss for the 2 training session of the 500 round :0.05658378452062607
# Epoch 2/100 - Train Loss: 0.1200, Train Acc: 0.9572
# Epoch 2/100 - Train Loss: 0.1200, Train Acc: 0.9572, Val Loss: 0.1976, Val Acc: 0.9308
# Validation loss decreased (0.230164 --> 0.197620).  Saving model ...
# Training on the 3 round
# loss for the 3 training session of the 100 round :0.11532855778932571
# loss for the 3 training session of the 200 round :0.1199786365032196
# loss for the 3 training session of the 300 round :0.043285857886075974
# loss for the 3 training session of the 400 round :0.04103053733706474
# loss for the 3 training session of the 500 round :0.08737034350633621
# Epoch 3/100 - Train Loss: 0.0877, Train Acc: 0.9679
# Epoch 3/100 - Train Loss: 0.0877, Train Acc: 0.9679, Val Loss: 0.1162, Val Acc: 0.9586
# Validation loss decreased (0.197620 --> 0.116165).  Saving model ...
# Training on the 4 round
# loss for the 4 training session of the 100 round :0.08896378427743912
# loss for the 4 training session of the 200 round :0.1245160773396492
# loss for the 4 training session of the 300 round :0.01010863110423088
# loss for the 4 training session of the 400 round :0.02724396623671055
# loss for the 4 training session of the 500 round :0.0311347134411335
# Epoch 4/100 - Train Loss: 0.0723, Train Acc: 0.9740
# Epoch 4/100 - Train Loss: 0.0723, Train Acc: 0.9740, Val Loss: 0.1000, Val Acc: 0.9635
# Validation loss decreased (0.116165 --> 0.099963).  Saving model ...
# Training on the 5 round
# loss for the 5 training session of the 100 round :0.08147827535867691
# loss for the 5 training session of the 200 round :0.13073958456516266
# loss for the 5 training session of the 300 round :0.06385485827922821
# loss for the 5 training session of the 400 round :0.09593290835618973
# loss for the 5 training session of the 500 round :0.14581520855426788
# Epoch 5/100 - Train Loss: 0.0680, Train Acc: 0.9751
# Epoch 5/100 - Train Loss: 0.0680, Train Acc: 0.9751, Val Loss: 0.1202, Val Acc: 0.9581
# EarlyStopping counter: 1 out of 7
# Training on the 6 round
# loss for the 6 training session of the 100 round :0.01013548020273447
# loss for the 6 training session of the 200 round :0.053598783910274506
# loss for the 6 training session of the 300 round :0.029212942346930504
# loss for the 6 training session of the 400 round :0.05549553409218788
# loss for the 6 training session of the 500 round :0.10052645951509476
# Epoch 6/100 - Train Loss: 0.0594, Train Acc: 0.9786
# Epoch 6/100 - Train Loss: 0.0594, Train Acc: 0.9786, Val Loss: 0.0981, Val Acc: 0.9673
# Validation loss decreased (0.099963 --> 0.098071).  Saving model ...
# Training on the 7 round
# loss for the 7 training session of the 100 round :0.06684993952512741
# loss for the 7 training session of the 200 round :0.017202187329530716
# loss for the 7 training session of the 300 round :0.08692429214715958
# loss for the 7 training session of the 400 round :0.20191195607185364
# loss for the 7 training session of the 500 round :0.011632791720330715
# Epoch 7/100 - Train Loss: 0.0576, Train Acc: 0.9794
# Epoch 7/100 - Train Loss: 0.0576, Train Acc: 0.9794, Val Loss: 0.1220, Val Acc: 0.9542
# EarlyStopping counter: 1 out of 7
# Training on the 8 round
# loss for the 8 training session of the 100 round :0.04058540239930153
# loss for the 8 training session of the 200 round :0.17485447227954865
# loss for the 8 training session of the 300 round :0.03113122098147869
# loss for the 8 training session of the 400 round :0.08386218547821045
# loss for the 8 training session of the 500 round :0.036927480250597
# Epoch 8/100 - Train Loss: 0.0519, Train Acc: 0.9811
# Epoch 8/100 - Train Loss: 0.0519, Train Acc: 0.9811, Val Loss: 0.0969, Val Acc: 0.9700
# Validation loss decreased (0.098071 --> 0.096932).  Saving model ...
# Training on the 9 round
# loss for the 9 training session of the 100 round :0.011939864605665207
# loss for the 9 training session of the 200 round :0.04807892069220543
# loss for the 9 training session of the 300 round :0.04777757450938225
# loss for the 9 training session of the 400 round :0.047715410590171814
# loss for the 9 training session of the 500 round :0.03557147830724716
# Epoch 9/100 - Train Loss: 0.0516, Train Acc: 0.9816
# Epoch 9/100 - Train Loss: 0.0516, Train Acc: 0.9816, Val Loss: 0.0888, Val Acc: 0.9695
# Validation loss decreased (0.096932 --> 0.088796).  Saving model ...
# Training on the 10 round
# loss for the 10 training session of the 100 round :0.07114621996879578
# loss for the 10 training session of the 200 round :0.0409419983625412
# loss for the 10 training session of the 300 round :0.02420045994222164
# loss for the 10 training session of the 400 round :0.06157304719090462
# loss for the 10 training session of the 500 round :0.008863253518939018
# Epoch 10/100 - Train Loss: 0.0477, Train Acc: 0.9830
# Epoch 10/100 - Train Loss: 0.0477, Train Acc: 0.9830, Val Loss: 0.0947, Val Acc: 0.9673
# EarlyStopping counter: 1 out of 7
# Training on the 11 round
# loss for the 11 training session of the 100 round :0.015907540917396545
# loss for the 11 training session of the 200 round :0.08797179162502289
# loss for the 11 training session of the 300 round :0.049794189631938934
# loss for the 11 training session of the 400 round :0.0479828342795372
# loss for the 11 training session of the 500 round :0.018728962168097496
# Epoch 11/100 - Train Loss: 0.0461, Train Acc: 0.9840
# Epoch 11/100 - Train Loss: 0.0461, Train Acc: 0.9840, Val Loss: 0.1660, Val Acc: 0.9477
# EarlyStopping counter: 2 out of 7
# Training on the 12 round
# loss for the 12 training session of the 100 round :0.06720055639743805
# loss for the 12 training session of the 200 round :0.05478596314787865
# loss for the 12 training session of the 300 round :0.009088937193155289
# loss for the 12 training session of the 400 round :0.056033533066511154
# loss for the 12 training session of the 500 round :0.015821212902665138
# Epoch 12/100 - Train Loss: 0.0386, Train Acc: 0.9861
# Epoch 12/100 - Train Loss: 0.0386, Train Acc: 0.9861, Val Loss: 0.0876, Val Acc: 0.9711
# Validation loss decreased (0.088796 --> 0.087629).  Saving model ...
# Training on the 13 round
# loss for the 13 training session of the 100 round :0.023803960531949997
# loss for the 13 training session of the 200 round :0.03362457826733589
# loss for the 13 training session of the 300 round :0.006357563193887472
# loss for the 13 training session of the 400 round :0.004107636399567127
# loss for the 13 training session of the 500 round :0.09324941784143448
# Epoch 13/100 - Train Loss: 0.0351, Train Acc: 0.9882
# Epoch 13/100 - Train Loss: 0.0351, Train Acc: 0.9882, Val Loss: 0.0916, Val Acc: 0.9722
# EarlyStopping counter: 1 out of 7
# Training on the 14 round
# loss for the 14 training session of the 100 round :0.019536323845386505
# loss for the 14 training session of the 200 round :0.022697271779179573
# loss for the 14 training session of the 300 round :0.09236716479063034
# loss for the 14 training session of the 400 round :0.0110164200887084
# loss for the 14 training session of the 500 round :0.05441820248961449
# Epoch 14/100 - Train Loss: 0.0342, Train Acc: 0.9881
# Epoch 14/100 - Train Loss: 0.0342, Train Acc: 0.9881, Val Loss: 0.0879, Val Acc: 0.9700
# EarlyStopping counter: 2 out of 7
# Training on the 15 round
# loss for the 15 training session of the 100 round :0.007681552320718765
# loss for the 15 training session of the 200 round :0.004895440768450499
# loss for the 15 training session of the 300 round :0.013377333991229534
# loss for the 15 training session of the 400 round :0.0289289727807045
# loss for the 15 training session of the 500 round :0.0036521023139357567
# Epoch 15/100 - Train Loss: 0.0333, Train Acc: 0.9884
# Epoch 15/100 - Train Loss: 0.0333, Train Acc: 0.9884, Val Loss: 0.0812, Val Acc: 0.9728
# Validation loss decreased (0.087629 --> 0.081227).  Saving model ...
# Training on the 16 round
# loss for the 16 training session of the 100 round :0.005688382778316736
# loss for the 16 training session of the 200 round :0.012696478515863419
# loss for the 16 training session of the 300 round :0.011005544103682041
# loss for the 16 training session of the 400 round :0.04557853937149048
# loss for the 16 training session of the 500 round :0.03259527310729027
# Epoch 16/100 - Train Loss: 0.0304, Train Acc: 0.9899
# Epoch 16/100 - Train Loss: 0.0304, Train Acc: 0.9899, Val Loss: 0.1679, Val Acc: 0.9455
# EarlyStopping counter: 1 out of 7
# Training on the 17 round
# loss for the 17 training session of the 100 round :0.0669824406504631
# loss for the 17 training session of the 200 round :0.10987268388271332
# loss for the 17 training session of the 300 round :0.17232829332351685
# loss for the 17 training session of the 400 round :0.02734673209488392
# loss for the 17 training session of the 500 round :0.006856363732367754
# Epoch 17/100 - Train Loss: 0.0278, Train Acc: 0.9908
# Epoch 17/100 - Train Loss: 0.0278, Train Acc: 0.9908, Val Loss: 0.1323, Val Acc: 0.9548
# EarlyStopping counter: 2 out of 7
# Training on the 18 round
# loss for the 18 training session of the 100 round :0.012643135152757168
# loss for the 18 training session of the 200 round :0.02562873438000679
# loss for the 18 training session of the 300 round :0.002249322831630707
# loss for the 18 training session of the 400 round :0.021958185359835625
# loss for the 18 training session of the 500 round :0.011895107105374336
# Epoch 18/100 - Train Loss: 0.0270, Train Acc: 0.9904
# Epoch 18/100 - Train Loss: 0.0270, Train Acc: 0.9904, Val Loss: 0.1021, Val Acc: 0.9717
# EarlyStopping counter: 3 out of 7
# Training on the 19 round
# loss for the 19 training session of the 100 round :0.034638579934835434
# loss for the 19 training session of the 200 round :0.010371197946369648
# loss for the 19 training session of the 300 round :0.046721141785383224
# loss for the 19 training session of the 400 round :0.0013026612577959895
# loss for the 19 training session of the 500 round :0.008856838569045067
# Epoch 19/100 - Train Loss: 0.0237, Train Acc: 0.9921
# Epoch 19/100 - Train Loss: 0.0237, Train Acc: 0.9921, Val Loss: 0.1873, Val Acc: 0.9483
# EarlyStopping counter: 4 out of 7
# Training on the 20 round
# loss for the 20 training session of the 100 round :0.0025099925696849823
# loss for the 20 training session of the 200 round :0.04744911938905716
# loss for the 20 training session of the 300 round :0.007870611734688282
# loss for the 20 training session of the 400 round :0.0008627647766843438
# loss for the 20 training session of the 500 round :0.0321614146232605
# Epoch 20/100 - Train Loss: 0.0230, Train Acc: 0.9921
# Epoch 20/100 - Train Loss: 0.0230, Train Acc: 0.9921, Val Loss: 0.1674, Val Acc: 0.9499
# EarlyStopping counter: 5 out of 7
# Training on the 21 round
# loss for the 21 training session of the 100 round :0.003834366798400879
# loss for the 21 training session of the 200 round :0.04691589996218681
# loss for the 21 training session of the 300 round :0.013032082468271255
# loss for the 21 training session of the 400 round :0.0018374815117567778
# loss for the 21 training session of the 500 round :0.004318702034652233
# Epoch 21/100 - Train Loss: 0.0203, Train Acc: 0.9929
# Epoch 21/100 - Train Loss: 0.0203, Train Acc: 0.9929, Val Loss: 0.0909, Val Acc: 0.9711
# EarlyStopping counter: 6 out of 7
# Training on the 22 round
# loss for the 22 training session of the 100 round :0.008517177775502205
# loss for the 22 training session of the 200 round :0.010157139971852303
# loss for the 22 training session of the 300 round :0.028350582346320152
# loss for the 22 training session of the 400 round :0.0048215859569609165
# loss for the 22 training session of the 500 round :0.01931249536573887
# Epoch 22/100 - Train Loss: 0.0183, Train Acc: 0.9935
# Epoch 22/100 - Train Loss: 0.0183, Train Acc: 0.9935, Val Loss: 0.0946, Val Acc: 0.9690
# EarlyStopping counter: 7 out of 7
# Early stopping
# 35592
# 35592
# 1836
# 1836

# %%
# Load the test dataset
data_dir = '/home/ym62/Group_Classification/' 

# Define the data loading function for the test set
def get_test_loader(data_dir, batch_size):
    normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                     std=[0.5, 0.5, 0.5])

    transform = transforms.Compose([
        transforms.Resize(224),
        transforms.ToTensor(),
        normalize
    ])

    test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, 'test'), transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4)

    return test_loader
test_loader = get_test_loader(data_dir, batch_size=best_params['batch_size'])

#test_dataset = datasets.ImageFolder(root=os.path.join(data_dir, 'test'))

# %%
# Evaluate the model on the test set

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = best_model.to(device)
model.eval()

test_preds = []
test_labels = []

with torch.no_grad():
    for imgs, targets in test_loader:
        imgs, targets = imgs.to(device), targets.to(device)
        outputs = model(imgs)
        _, preds = torch.max(outputs, 1)

        test_preds.extend(preds.cpu().numpy())
        test_labels.extend(targets.cpu().numpy())

# Calculate metrics
accuracy = accuracy_score(test_labels, test_preds)
balanced_acc = balanced_accuracy_score(test_labels, test_preds)
f1 = f1_score(test_labels, test_preds, average='weighted')
precision = precision_score(test_labels, test_preds, average='weighted')
recall = recall_score(test_labels, test_preds, average='weighted')

print(f'Accuracy: {accuracy:.4f}')
print(f'Balanced Accuracy: {balanced_acc:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')

# Plot confusion matrix
class_names = test_loader.dataset.classes
plot_confusion_matrix(test_labels, test_preds, class_names, title="Test Set Confusion Matrix")
# Out:
# Accuracy: 0.9663
# Balanced Accuracy: 0.8017
# F1 Score: 0.9666
# Precision: 0.9671
# Recall: 0.9663
# 1842
# 1842
